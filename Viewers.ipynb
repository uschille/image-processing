# %%
# %matplotlib notebook
import skimage.io
image = skimage.io.imread(fname="code/03-skimage-images/chair.jpg")
skimage.io.imshow(image)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import hyperspy.api as hs
#img = hs.load("code/02-image-basics/tree.jpg")
image = skimage.io.imread("code/02-image-basics/tree.jpg")
img = hs.signals.Signal2D(image.view(dtype=[('R', 'u1'), ('G', 'u1'), ('B', 'u1')]).reshape(image.shape[:-1]))
img.plot()
# Out:
# WARNING:hyperspy_gui_traitsui:The nbAgg matplotlib backend is not compatible with the traitsui GUI elements. For more information, read http://hyperspy.readthedocs.io/en/stable/user_guide/getting_started.html#possible-warnings-when-importing-hyperspy.
# WARNING:hyperspy_gui_traitsui:The traitsui GUI elements are not available.
# <img src="data:image/png;base64,..." width="640">

# %%
# %gui qt
import napari
image = skimage.io.imread("code/02-image-basics/tree.jpg")
viewer = napari.view_image(image)
napari.utils.nbscreenshot(viewer)

# %%
from magicgui import magicgui

@magicgui
def my_widget(viewer: napari.Viewer):
    viewer.add_image(image)

viewer=napari.Viewer()
my_widget(viewer)

# %%
from napari.layers import Image

@magicgui(call_button='Add Image')
def my_widget(ny: int=64, nx: int=64) -> Image:
  return Image(image)

viewer = napari.Viewer()
viewer.window.add_dock_widget(my_widget, area='right')
my_widget()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-4c393187e197> in <module>
#       6
#       7 viewer = napari.Viewer()
# ----> 8 viewer.window.add_dock_widget(my_widget, area='right')
#       9 my_widget()
#
# ~/.local/lib/python3.6/site-packages/napari/_qt/qt_main_window.py in add_dock_widget(self, widget, name, area, allowed_areas, shortcut)
#     376             area=area,
#     377             allowed_areas=allowed_areas,
# --> 378             shortcut=shortcut,
#     379         )
#     380         self._add_viewer_dock_widget(dock_widget)
#
# ~/.local/lib/python3.6/site-packages/napari/_qt/widgets/qt_viewer_dock_widget.py in __init__(self, qt_viewer, widget, name, area, allowed_areas, shortcut)
#      81
#      82         self.widget = combine_widgets(
# ---> 83             widget, vertical=area in {'left', 'right'}
#      84         )
#      85         self._features = self.features()
#
# ~/.local/lib/python3.6/site-packages/napari/_qt/utils.py in combine_widgets(widgets, vertical)
#     184         return container
#     185     else:
# --> 186         raise TypeError('"widget" must be a QWidget or a sequence of QWidgets')
#
# TypeError: "widget" must be a QWidget or a sequence of QWidgets
